# %% [markdown]
# **Print** and **Type** functions are the most widely funcations in python

# %% [markdown]
# # **Data Types**

# %% [markdown]
# **integers**

# %%
print(5)
# Out:
# 5

# %%
type(5)
# Out:
# int

# %%
type(8383)
# Out:
# int

# %% [markdown]
# **Float**

# %%
print(6.7)
# Out:
# 6.7

# %%
type(5.6)
# Out:
# float

# %%
type(-0.2)
# Out:
# float

# %% [markdown]
# **Complex Numbers**

# %%
print(3+2j)
# Out:
# (3+2j)

# %%
type(3+2j)
# Out:
# complex

# %% [markdown]
# **Boolean**
#
# True, Flase  ----> Boolean
#
# true, false  -----> Not Boolean

# %%
type(True)
# Out:
# bool

# %%
type(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 type(true)
#
# NameError: name 'true' is not defined

# %%
 1 == 2
# Out:
# False

# %%
3 > 2
# Out:
# True

# %%
3+4 == 7
# Out:
# True

# %% [markdown]
# **Strings**
#
# Text or characters inside " " or ' ' is **string**

# %%
print(well_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(well_name)
#
# NameError: name 'well_name' is not defined

# %%
print("well name")
# Out:
# well name

# %%
print("true")
# Out:
# true

# %%
print(True)
print(type(True))
# Out:
# True
# <class 'bool'>

# %%
print('True')
print(type('True'))
# Out:
# True
# <class 'str'>

# %%
type(23)
# Out:
# int

# %%
type('23')
# Out:
# str

# %% [markdown]
# **Mathematical Operations**

# %%
#Addition 

print(5+7)
# Out:
# 12

# %%
#Subtraction 

print(7- 2)
# Out:
# 5

# %%
#Division 

#float division

print(14/3)
# Out:
# 4.666666666666667

# %%
#integer division

print(14//3)
# Out:
# 4

# %%
#Modulo (%)  ---> Remainder of integer division

print(14%3)
# Out:
# 2

# %%
#Multiplication

print(5*473)
# Out:
# 2365

# %%
print(6.2 * 5.2)
# Out:
# 32.24

# %%
#Exponent

print(4**3)
# Out:
# 64

# %%
print(2**5)
# Out:
# 32

# %%
print(sqrt(64))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 print(sqrt(64))
#
# NameError: name 'sqrt' is not defined

# %%
import math
print(math.sqrt(64))
# Out:
# 8.0
